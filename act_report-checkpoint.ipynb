# %% [markdown]
# ## Report: act_report

# %% [markdown]
# ### Insights after analyzing data

# %% [markdown]
# #### 1. The dog_stage floofer has the highest average rating with pupper having the lowest.
#
# This is evidenced by pandas groupby method, that groups dog_stage by rating numerator, then finding average rating.
# The findings indicate the highest ratings belonging to floofer and the least ratings to pupper.
# However this does not accurately determine the dog stage with the highest rating as we would have to look at other factors.

# %% [markdown]
# #### 2. Averagely 25% of the dog predictions are not dog breeds.
# Finding percentage value counts for True and False values. True affriming dog breed to being in existence while False tells that the dog breed is non existant. For the first prediction percentage of false values is 26.02, second prediction is 24.89 and third prediction is 27.76.

# %% [markdown]
# #### 3. Most of the dogs are in the pupper stage.
# Performaing value_counts for each dog_stage shows that puppers are more in numbers than the rest.

# %% [markdown]
# #### 4. The doggo have most favorite counts with pupper having the least.
# Performing a groupby function of dog_stage by favorite count, doggos have more favourite counts as compared to pupper.

# %% [markdown]
# #### 4. In comparison to the number of dogs in each dog stage, the puppers have the highest ratings.
# Due to their high numbers the pupper ratings are generally higher than the rest.
# Below is a Visualization affriming the same.

# %% [markdown]
# ![download.png](attachment:download.png)
